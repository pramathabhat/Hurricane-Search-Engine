# %%
import os
from nltk.tokenize import word_tokenize
from nltk.stem import PorterStemmer
import re
import json

# %%
def stem_text(text, ps):
    stemmed = ' '.join([ps.stem(word) for word in text.split()])
    return stemmed

# %%
def update_text_map_with_links(inlinks_file, outlinks_file):
    with open(inlinks_file, 'r') as inlinks_json, open(outlinks_file, 'r') as outlinks_json:
        inlinks_data = json.load(inlinks_json)
        outlinks_data = json.load(outlinks_json)
        
        for doc_id, inlinks in inlinks_data.items():
            if doc_id in text_map:
                text_map[doc_id]['inlinks'] = inlinks
        for doc_id, outlinks in outlinks_data.items():
            if doc_id in text_map:
                text_map[doc_id]['outlinks'] = outlinks

# %%
text_map = {}
ps = PorterStemmer()

def parse_file(file_path):
    current_doc_no = None
    reading_text = False
    doc_text = ""
    count = 0
    # parse the doc to get doc no and corresponding text
    with open(file_path, 'r', encoding='ISO-8859-1', errors='ignore') as file:
        lines = file.readlines()
    for line in lines:
        if "<DOCNO>" in line:
            current_doc_no = line.strip().replace('<DOCNO>', '').replace('</DOCNO>', '')
        elif "<HEAD>" in line:
            doc_title = line.strip().replace('<HEAD>', '').replace('</HEAD>', '')
        elif "<TEXT>" in line:
            reading_text = True
            if "</TEXT>" in line:
                    doc_text += line.split("<TEXT>")[1].split("</TEXT>")[0].strip() + ' '
                    reading_text = False
        elif "</TEXT>" in line:
            reading_text = False
        elif reading_text:
            doc_text += line.strip() + ' '
        elif "</DOC>" in line:
            if current_doc_no is not None:
                stemmed_text = stem_text(doc_text, ps)
                text_map[current_doc_no.strip()] = {'title': doc_title, 'text': stemmed_text.strip()}
                doc_text = ""
                doc_title = ""

# %%
file_path = "hurricane_data_final.txt"

parse_file(file_path)
print("Parsing completed")
# Out:
# Parsing completed

# %%
inlinks_file_path = "hurricane_inlinks_final.json"
outlinks_file_path = "hurricane_outlinks_final.json"
update_text_map_with_links(inlinks_file_path, outlinks_file_path)

print("Inlinks and outlinks added")
# Out:
# Inlinks and outlinks added

# %%
#total no of docs
print(len(text_map))
# Out:
# 30000

# %%
#save doc id into a list
docnos = list(text_map.keys())
first_doc_id = docnos[0]

first_doc_value = text_map.get(first_doc_id)

first_doc_value
# Out:
# {'title': 'Cyclone Imogen - Wikipedia',
#  'text': "tropic cyclon imogen wa a weak but damag tropic cyclon that affect part of northern queensland. the sixth tropic low, and the first cyclon of the 2020â\x80\x9321 australian region cyclon season, imogen origin from a tropic low that form in the western gulf of carpentaria. imogen caus minim destruct on the northern part of queensland as a categori 2 cyclone, caus approxim $10 million in damages.[1] on 1 january, the bureau of meteorolog (bom) report that a tropic low had form near groot eylandt in the western gulf of carpentaria, locat about 635 km (395 mi) east-southeast of darwin.[2] the system wa assign the identifi code 05u by the bom.[3] environment condit were assess as be favour for tropic cyclogenesis, characteris by veri warm sea surfac temperatur of up to 31 â°c (88 â°f), low to moder vertic wind shear and an establish poleward outflow channel in the upper levels.[4] flare convect began to develop around the consolid low-level circul centr as the system track southeastward over the gulf of carpentaria, and at 00:00 utc on 2 january, the bom issu a tropic cyclon watch for part of the northwestern queensland coast.[4][5] the tropic low continu to strengthen as convect rainband began to wrap into the system' centre, with moist northwesterli cross-equatori flow from over indonesia feed the system in the low to mid troposphere.[3] by 18:00 utc, vertic wind shear valu had decreas further as the tropic low move underneath an upper-level ridge; however, despit the highli favour environment conditions, intensif wa limit somewhat by the broad and elong natur of the low-level circul center.[6] the joint typhoon warn center (jtwc) issu a tropic cyclon format alert for the system at 20:00 utc.[7] tropic low 05u made landfal on the western coast of mornington island at around 02:00 utc on 3 january, with maximum sustain wind near the centr of 55 km/h (34 mph).[8] intensif proceed as the system re-emerg over the gulf of carpentaria a few hour later, with spiral rainband continu to develop around the centr of the system and deep convect becom more concentrated. at 06:00 utc, the tropic low wa upgrad to a categori 1 tropic cyclon by the bom, and wa name imogen, becom the first tropic cyclon of the 2020â\x80\x9321 australian region cyclon season.[9][10] at the same time, the jtwc indic that maximum one-minut sustain wind had increas to 65 km/h (40 mph), make imogen equival to a tropic storm on the saffirâ\x80\x93simpson hurrican wind scale.[11] in combin with the low-level northwesterli flow, an upper-tropospher trough situat to the south of the system began to gradual acceler imogen toward the southeast. deep convect continu to concentr over the centr of the cyclone; however, due to the system' proxim to land, limit time wa avail for further intensification.[12] tropic cyclon imogen made landfal just to the north of karumba, queensland, at 11:00 utc on 3 january.[13][14] at the time of landfall, maximum 10-minut sustain wind were estim at 65 km/h (40 mph), with gust to 100 km/h (62 mph) and a minimum atmospher pressur of 994 hpa (29.35 inhg).[12] the jtwc report that maximum one-minut sustain wind had reach 85 km/h (53 mph) by thi time.[15] despit the centr of the system track over land, imogen maintain it organis for sever hours, assist by the flat terrain that had been satur by heavi rainfal gener by the cyclone.[14] the bom report that maximum 10-minut sustain wind peak at 85 km/h (53 mph), with gust to 110 km/h (68 mph), at 15:00 utc on 3 januaryâ\x80\x94about four hour after landfallâ\x80\x94a the cyclon wa pass to the northeast of normanton.[16] at thi time, the automat weather station at the town' airport record a minimum atmospher pressur of 989.3 hpa (29.21 inhg).[17] imogen later acceler north-east befor final dissip on januari 6.[18] the bom maintain cyclon warn for the inland gulf countri includ croydon due to cyclon imogen.[19] as cyclon imogen blast portion of north-west queensland, it left extens damag behind. ...
#  'inlinks': ['http://en.wikipedia.org/wiki/Cyclone_Seroja',
#   'http://en.wikipedia.org/wiki/Cyclone_Kimi',
#   'http://en.wikipedia.org/wiki/Cyclone_Les',
#   'http://en.wikipedia.org/wiki/Cyclone_Tiffany',
#   'http://en.wikipedia.org/wiki/List_of_historic_tropical_cyclone_names',
#   'http://en.wikipedia.org/wiki/2020-21_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/
Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Portal:Current_events',
#   'http://en.wikipedia.org',
#   'http://en.wikipedia.org/wiki/1998%E2%80%9399_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/1999%E2%80%932000_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Category:Category_2_Australian_region_cyclones',
#   'http://en.wikipedia.org/wiki/Celsius',
#   'http://en.wikipedia.org/wiki/Normanton_Airport',
#   'http://www.bom.gov.au/cgi-bin/wrap_fwo.pl?IDQ20018.txt',
#   'http://en.wikipedia.org',
#   'http://en.wikipedia.org/wiki/Wikipedia:Link_rot',
#   'http://en.wikipedia.org/wiki/Darwin,_Northern_Territory',
#   'https://archive.today/20210103074357/http:/www.bom.gov.au/products/IDQ65002.shtml',
#   'http://en.wikipedia.org/wiki/Joint_Typhoon_Warning_Center',
#   'http://en.wikipedia.org/wiki/2020%E2%80%9321_Australian_region_cyclone_season',
#   'https://archive.today/20210103195432/https:/www.metoc.navy.mil/jtwc/products/sh0921web.txt',
#   'http://en.wikipedia.org/wiki/1969%E2%80%9370_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Extratropical_cyclone',
#   'http://en.wikipedia.org/wiki/Help:Introduction',
#   'http://en.wikipedia.org/wiki/Template_talk:Category_2_Australian_region_tropical_cyclones',
#   'http://en.wikipedia.org/wiki/2008%E2%80%9309_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/1992%E2%80%9393_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Help:Category',
#   'http://foundation.wikimedia.org/wiki/Special:MyLanguage/Policy:Terms_of_Use',
#   'http://en.wikipedia.org/wiki/Croydon',
#   'http://en.wikipedia.org/wiki/Special:EditPage/Template:2020%E2%80%9321_Australian_region_cyclone_season_buttons',
#   'http://en.wikipedia.org/wiki/1981%E2%80%9382_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Template:2020%E2%80%9321_Australian_region_cyclone_season_buttons',
#   'http://en.wikipedia.org/wiki/2009%E2%80%9310_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/1975%E2%80%9376_Australian_region_cyclone_season',
#   'http://www.bom.gov.au/cgi-bin/wrap_fwo.pl?IDQ20018.txt',
#   'http://en.wikipedia.org/wiki/Inch_of_mercury',
#   'http://www.bom.gov.au/nt/forecasts/tcoutlook.shtml',
#   'http://en.wikipedia.org/wiki/2016%E2%80%9317_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Help:Template',
#   'http://en.wikipedia.org/wiki/2009%E2%80%9310_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Help:Introduction',
#   'http://en.wikipedia.org/wiki/Tropical_Cyclone_Formation_Alert',
#   'http://en.wikipedia.org/wiki/1990%E2%80%9391_Australian_region_cyclone_season',
#   'https://archive.today/20210101074536/http:/www.bom.gov.au/nt/forecasts/tcoutlook.shtml',
#   'http://en.wikipedia.org/wiki/1995%E2%80%9396_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Wikipedia:WikiProject_Tropical_cyclones',
#   'http://en.wikipedia.org/wiki/Cyclone_Seth',
#   'http://en.wikipedia.org/wiki/1984%E2%80%9385_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Portal:Tropical_cyclones',
#   'http://en.wikipedia.org/wiki/Category:Commons_category_link_from_Wikidata',
#   'http://en.wikipedia.org/wiki/Cyclone_Kate_(2006)',
#   'http://en.wikipedia.org/wiki/Rain',
#   'http://en.wikipedia.org/wiki/1980%E2%80%9381_Australian_region_cyclone_season',
#   'http://en.wikipedia.org',
#   'http://en.wikipedia.org/wiki/1998%E2%80%9399_Australian_region_cyclone_season',
#   'http://en.wikipedia.org',
#   'http://en.wikipedia.org/wiki/Tropical_cyclones_in_2021',
#   'http://en.wikipedia.org/wiki/Cyclone_Jasmine',
#   'https://archive.today/20210103063021/http:/www.bom.gov.au/products/IDQ65002.shtml',
#   'http://en.wikipedia.org/wiki/2015%E2%80%9316_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/2020%E2%80%9321_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/2014%E2%80%9315_Australian_region_cyclone_season',
#   'https://archive.today/20210102042913/http:/www.bom.gov.au/products/IDQ65002.shtml',
#   'http://en.wikipedia.org/wiki/1996%E2%80%9397_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/2007%E2%80%9308_Australian_region_cyclone_season',
#   'https://www.wikidata.org/wiki/Special:EntityPage/Q108479524',
#   'http://en.wikipedia.org/wiki/File:Symbol_portal_class.svg',
#   'http://www.bom.gov.au/products/IDQ65002.shtml',
#   'https://archive.today/20210102190902/http:/www.bom.gov.au/cgi-bin/wrap_fwo.pl?IDQ20018.txt',
#   'http://en.wikipedia.org/wiki/Cyclone_Ann',
#   'http://en.wikipedia.org/wiki/2012%E2%80%9313_Australian_region_cyclone_season',
#   'http://www.bom.gov.au
Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Tropical_cyclone',
#   'http://en.wikipedia.org/wiki/1977%E2%80%9378_Australian_region_cyclone_season',
#   'https://archive.today/20210102113902/http:/www.bom.gov.au/cgi-bin/wrap_fwo.pl?IDQ20018.txt',
#   'http://en.wikipedia.org/wiki/1997%E2%80%9398_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Template:Hurricane_season_bar_gap',
#   'http://en.wikipedia.org',
#   'http://en.wikipedia.org/wiki/Groote_Eylandt',
#   'http://en.wikipedia.org/wiki/Special:SpecialPages',
#   'http://en.wikipedia.org',
#   'http://www.bom.gov.au/products/IDQ65002.shtml',
#   'https://archive.today/20210103080220/https:/www.metoc.navy.mil/jtwc/products/sh0921web.txt',
#   'http://en.wikipedia.org/wiki/2020%E2%80%9321_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/2020%E2%80%9321_Australian_region_cyclone_season',
#   'https://archive.today/20210103164920/http:/www.bom.gov.au/products/IDQ65002.shtml',
#   'http://en.wikipedia.org/wiki/1998%E2%80%9399_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/1988%E2%80%9389_Australian_region_cyclone_season',
#   'http://en.wikipedia.org/wiki/Category:Pages_using_obsolete_storm_path_colors']}

# %%
sw_path = "../config/stoplistnltk.txt"

with open(sw_path) as file:
    stopwords = file.read().splitlines()

print(len(stopwords))
# Out:
# 418

# %%
import string

def process_content(text):
    text = ' '.join([word.lower() for word in text.split() if word.lower() not in stopwords])
    text = text.translate(str.maketrans("", "", string.punctuation))
    return text

# %%
author = "Pramatha"

processed_text_map = {doc_id: {'text': process_content(content['text']), 'author': author, **content} for doc_id, content in text_map.items()}

docnos = list(processed_text_map.keys())
first_doc_id = docnos[0]
first_doc_processed_content = processed_text_map[first_doc_id]

print(f"Document ID: {first_doc_id}")
print(f"Processed Content of the First Document: {first_doc_processed_content}")
# Out:
# Document ID: http://en.wikipedia.org/wiki/Cyclone_Imogen
# Processed Content of the First Document: {'text': "tropic cyclon imogen wa a weak but damag tropic cyclon that affect part of northern queensland. the sixth tropic low, and the first cyclon of the 2020â\x80\x9321 australian region cyclon season, imogen origin from a tropic low that form in the western gulf of carpentaria. imogen caus minim destruct on the northern part of queensland as a categori 2 cyclone, caus approxim $10 million in damages.[1] on 1 january, the bureau of meteorolog (bom) report that a tropic low had form near groot eylandt in the western gulf of carpentaria, locat about 635 km (395 mi) east-southeast of darwin.[2] the system wa assign the identifi code 05u by the bom.[3] environment condit were assess as be favour for tropic cyclogenesis, characteris by veri warm sea surfac temperatur of up to 31 â°c (88 â°f), low to moder vertic wind shear and an establish poleward outflow channel in the upper levels.[4] flare convect began to develop around the consolid low-level circul centr as the system track southeastward over the gulf of carpentaria, and at 00:00 utc on 2 january, the bom issu a tropic cyclon watch for part of the northwestern queensland coast.[4][5] the tropic low continu to strengthen as convect rainband began to wrap into the system' centre, with moist northwesterli cross-equatori flow from over indonesia feed the system in the low to mid troposphere.[3] by 18:00 utc, vertic wind shear valu had decreas further as the tropic low move underneath an upper-level ridge; however, despit the highli favour environment conditions, intensif wa limit somewhat by the broad and elong natur of the low-level circul center.[6] the joint typhoon warn center (jtwc) issu a tropic cyclon format alert for the system at 20:00 utc.[7] tropic low 05u made landfal on the western coast of mornington island at around 02:00 utc on 3 january, with maximum sustain wind near the centr of 55 km/h (34 mph).[8] intensif proceed as the system re-emerg over the gulf of carpentaria a few hour later, with spiral rainband continu to develop around the centr of the system and deep convect becom more concentrated. at 06:00 utc, the tropic low wa upgrad to a categori 1 tropic cyclon by the bom, and wa name imogen, becom the first tropic cyclon of the 2020â\x80\x9321 australian region cyclon season.[9][10] at the same time, the jtwc indic that maximum one-minut sustain wind had increas to 65 km/h (40 mph), make imogen equival to a tropic storm on the saffirâ\x80\x93simpson hurrican wind scale.[11] in combin with the low-level northwesterli flow, an upper-tropospher trough situat to the south of the system began to gradual acceler imogen toward the southeast. deep convect continu to concentr over the centr of the cyclone; however, due to the system' proxim to land, limit time wa avail for further intensification.[12] tropic cyclon imogen made landfal just to the north of karumba, queensland, at 11:00 utc on 3 january.[13][14] at the time of landfall, maximum 10-minut sustain wind were estim at 65 km/h (40 mph), with gust to 100 km/h (62 mph) and a minimum atmospher pressur of 994 hpa (29.35 inhg).[12] the jtwc report that maximum one-minut sustain wind had reach 85 km/h (53 mph) by thi time.[15] despit the centr of the system track over land, imogen maintain it organis for sever hours, assist by the flat terrain that had been satur by heavi rainfal gener by the cyclone.[14] the bom report that maximum 10-minut sustain wind peak at 85 km/h (53 mph), with gust to 110 km/h (68 mph), at 15:00 utc on 3 januaryâ\x80\x94about four hour after landfallâ\x80\x94a the cyclon wa pass to the northeast of normanton.[16] at thi time, the automat weather station at the town' airport record a minimum atmospher pressur of 989.3 hpa (29.21 inhg).[17] imogen later acceler north-east befor final dissip on januari 6.[18] the bom maintain cyclon warn for the inland gulf countri includ croydon due to cyclon imogen.[19] as cyclon imogen blast portion of north-west ...

# %% [markdown]
# # Merging elastic cloud index

# %%
# Merging Indexes
from elasticsearch7 import Elasticsearch
import os
from concurrent.futures import ThreadPoolExecutor
import time
import logging
import json

# Create an Index in Elasticsearch
def createIndex(index_name, stopwords) :
    if(es.indices.exists(index=index_name)):
        return
    configurations = {
        "settings" : {
            "number_of_shards": 1,
            "number_of_replicas": 1,
            "max_result_window" : 100000,
            "analysis": {
                "filter": {
                    "english_stop": {
                        "type": "stop",
                        "stopwords": stopwords
                    },
                },
                "analyzer": {
                    "stopped": {
                        "type": "custom",
                        "tokenizer": "standard",
                        "filter": [
                            "lowercase",
                            "english_stop",
                            "porter_stem"
                        ]
                    }
                }
            }
        },
        "mappings": {
            "properties": {
                "text": {
                    "type": "text",
                    "fielddata": True,
                    "analyzer": "stopped",
                    "index_options": "positions"
                },
                "title": {
                    "type": "text"
                },
                "author": {
                    "type": "text"
                },
                "inlinks": {
                    "type": "text"
                },
                "outlinks": {
                    "type": "text"
                },
                
                
            }
        }
    }
    es.indices.create(index=index_name, body=configurations)
    logging.info(f"Index with name : {index_name} has been created in Elastic Search")
    
def merge_indexes(index_name, processed_text_map) :
    print(es.ping())
    visited_urls = set()
    total_files = 1
    total_docs = 0
    for path in processed_text_map:
        total_docs += 1
        logging.info(f'Adding Data to Index : {path}')
        try:
            search_result = search_index(index_name, path)
            logging.info(f'Search Result for {path} completed')
            if exists_in_index(search_result) :
                logging.info(f'Merging started for {path}')
                authors = search_result["hits"]["hits"][0]["_source"]["author"]
                inlinks = set(search_result["hits"]["hits"][0]['_source']['inlinks'])
                outlinks = set(search_result["hits"]["hits"][0]['_source']['outlinks'])
                updated_authors = authors + "," + processed_text_map[path]['author']
                updated_inlinks = inlinks.union(processed_text_map[path]['inlinks'])
                updated_outlinks = outlinks.union(processed_text_map[path]['outlinks'])
                data_update = {
                    'doc' : {
                        'inlinks' : list(updated_inlinks),
                        'outlinks' : list(updated_outlinks),
                        'author' : updated_authors
                        }
                    }
                logging.info(f'Data Update for {path} started')
                es.update(index=index_name, id=path, body=data_update)
                logging.info(f'Data Update for {path} finished')
            else:
                es.index(index=index_name, id=path, body=processed_text_map[path])
                logging.info(f'Data Add for {path} finished')
            visited_urls.add(path)
        except Exception as e:
            logging.error(f'Failed to index {path} due to {e}')
        visited_urls.add(path)
        logging.info(f'Finished Adding data for {path}')
        logging.info(f'Completed Files : {total_files}, Remaining Files : {len(processed_text_map) - total_files}, Total Docs : {len(visited_urls)}')
        total_files +=1
    logging.info(f'Total Set : {len(visited_urls)}')
    return visited_urls
            

def search_index(index_name, docID) :    
    response = es.search(index=index_name, query={"match": {"_id": docID}})
    return response

def exists_in_index(response) :
    return response['hits']['total']['value'] > 0

# %%
cloud_id = 'webcrawler:dXMtY2VudHJhbDEuZ2NwLmNsb3VkLmVzLmlvOjQ0MyRhNWRhNGY1MTQ3Yjk0YmYwODAyMWJhMTQ0NDM5ZDU1NiQ3NWNiNjM4ZjM1ODA0ZmRjOWU1NTA0N2FhM2U3YWJiZA=='
es = Elasticsearch(cloud_id = cloud_id, request_timeout=3000, http_auth = ('elastic', 'bZRNn0IN9wzKsH3VacukXFXW'))
index_name = 'recent_hurricanes'
logging.basicConfig(
            level=logging.INFO,
            format="%(asctime)s [%(levelname)s] %(message)s\n",
            filename="index_merger_logs.txt",
            filemode="a"
)
start_time = time.time()
# createIndex(index_name, [])
visited_urls = merge_indexes(index_name, processed_text_map)
end_time = time.time()
print(f'Ended indexing the data in {end_time - start_time} seconds')
# Out:
# True
# C:\Users\Pramatha\AppData\Local\Temp\ipykernel_5780\3284239483.py:93: DeprecationWarning: The 'body' parameter is deprecated for the 'update' API and will be removed in a future version. Instead use API parameters directly. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   es.update(index=index_name, id=path, body=data_update)
# C:\Users\Pramatha\AppData\Local\Temp\ipykernel_5780\3284239483.py:96: DeprecationWarning: The 'body' parameter is deprecated for the 'index' API and will be removed in a future version. Instead use the 'document' parameter. See https://github.com/elastic/elasticsearch-py/issues/1698 for more information
#   es.index(index=index_name, id=path, body=processed_text_map[path])
# Ended indexing the data in 6257.730765342712 seconds
